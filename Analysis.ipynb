# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
borough_months = pd.read_excel("Crime/Borough Monthly 2018-20.xlsx")
# borough_months = borough_months.groupby(by=borough_months["OCU Name"]).sum()
borough_months = borough_months.sort_values(by="Month-Year")
borough_months
# Out:
#                   OCU Name Month-Year  11 Violence Against the Person Offs  \
# 0       Barking & Dagenham 2018-01-01                                  432
# 1116            Wandsworth 2018-01-01                                  546
# 72                  Bexley 2018-01-01                                  329
# 1080        Waltham Forest 2018-01-01                                  523
# 108                  Brent 2018-01-01                                  667
# ...                    ...        ...                                  ...
# 791                Lambeth 2020-12-01                                  617
# 1007             Southwark 2020-12-01                                  610
# 143                  Brent 2020-12-01                                  745
# 755   Kingston upon Thames 2020-12-01                                  261
# 1187           Westminster 2020-12-01                                  641
#
#       12 Sexual Offences Offs  13 Robbery Offs  14 Burglary Offs  \
# ...

# %%
print(borough_months["Month-Year"])
# Out:
# 0      2018-01-01
# 1116   2018-01-01
# 72     2018-01-01
# 1080   2018-01-01
# 108    2018-01-01
#           ...
# 791    2020-12-01
# 1007   2020-12-01
# 143    2020-12-01
# 755    2020-12-01
# 1187   2020-12-01
# Name: Month-Year, Length: 1188, dtype: datetime64[ns]
